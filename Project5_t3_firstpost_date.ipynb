# %%
import numpy as np
import statsmodels.api as sm
import json
import datetime, time
import collections
from sklearn import metrics

hashtags = ['gohawks', 'gopatriots' , 'nfl', 'patriots' , 'sb49', 'superbowl']
results = []

for ht in hashtags:
    print(ht)
    tweets = open('tweets_#' + ht + '.txt', 'r', encoding="utf8")
    line = json.loads(tweets.readline())
    tweets.seek(0, 0)
    start_time = line.get('firstpost_date')
    number_of_tweets = 0
    number_of_retweets = 0
    number_of_followers = 0
    max_followers = 0
   

    hour_window = 1 # 1 hour window
    end_time = start_time + hour_window * 3600


    X = []
    Xi = [] # i => ith window
    Xi.append(1)
    Y = []

        
    for tweet in tweets:
        t = json.loads(tweet)
        if t.get('citation_date') < end_time:
            number_of_tweets = number_of_tweets + 1
            number_of_retweets = number_of_retweets + t.get('metrics').get('citations').get('total')
            number_of_followers = number_of_followers + t.get('tweet').get('user').get('followers_count')
            if t.get('tweet').get('user').get('followers_count') > max_followers:
                max_followers = t.get('tweet').get('user').get('followers_count')
        else:
            Xi.append(number_of_tweets)
            Y.append(number_of_tweets)
            number_of_tweets = 1           

            Xi.append(number_of_retweets)
            number_of_retweets = t.get('metrics').get('citations').get('total')
            Xi.append(number_of_followers)
            number_of_followers = t.get('tweet').get('user').get('followers_count')
            Xi.append(max_followers)
            max_followers = t.get('tweet').get('user').get('followers_count')
            Xi.append(int(datetime.datetime.fromtimestamp(t.get('firstpost_date')).strftime("%H")))

            end_time = end_time + hour_window * 3600
            X.append(Xi)
            Xi = []
            Xi.append(1)       

    Y = collections.deque(Y)
    Y.rotate(-1)
    Y = list(Y)

    res = sm.OLS(Y, X).fit()
    results.append(res)   
  
    
    Y_pred = res.predict()
    
    # calculate MAE, MSE, RMSE
    print("+++++++++++++++++++++++++++++++++")
    print("Mean Absolute Error", metrics.mean_absolute_error(Y, Y_pred))
    print("Mean Square Error", metrics.mean_squared_error(Y, Y_pred))
    print("Root Mean-Square Error" , np.sqrt(metrics.mean_squared_error(Y, Y_pred)))
    print("+++++++++++++++++++++++++++++++++")
    
    print(res.summary())
    #print('Parameters: ', res.params)
    #print('Standard errors: ', res.bse)
    #print('Predicted values: ', res.predict())
    #print('t_test: ', res.t_test)
    #print('p values: ', res.pvalues)
    #print('t values', res.tvalues)
    tweets.close()
# Out:
# gohawks
# +++++++++++++++++++++++++++++++++
# Mean Absolute Error 233.8595092554759
# Mean Square Error 773072.1330223832
# Root Mean-Square Error 879.2452064255928
# +++++++++++++++++++++++++++++++++
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.554
# Method:                 Least Squares   F-statistic:                     241.8
# Date:                Thu, 07 Jun 2018   Prob (F-statistic):          2.52e-167
# Time:                        14:11:17   Log-Likelihood:                -7952.1
# No. Observations:                 970   AIC:                         1.592e+04
# Df Residuals:                     964   BIC:                         1.595e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         42.3779     56.352      0.752      0.452     -68.208     152.964
# x1             0.4055      0.208      1.949      0.052      -0.003       0.814
# x2            -1.0611      0.072    -14.744      0.000      -1.202      -0.920
# x3             0.0011   6.93e-05     16.390      0.000       0.001       0.001
# x4            -0.0010      0.000     -7.560      0.000      -0.001      -0.001
# x5             6.2676      4.355      1.439      0.150      -2.279      14.814
# ==============================================================================
# Omnibus:                     1841.788   Durbin-Watson:                   1.783
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2882547.153
# Skew:                          13.485   Prob(JB):                         0.00
# Kurtosis:                     268.694   Cond. No.                     5.42e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.42e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# gopatriots
# +++++++++++++++++++++++++++++++++
# Mean Absolute Error 37.32223059774775
# Mean Square Error 37936.96819702904
# Root Mean-Square Error 194.77414663406702
# +++++++++++++++++++++++++++++++++
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.478
# Model:                            OLS   Adj. R-squared:                  0.474
# Method:                 Least Squares   F-statistic:                     109.9
# Date:                Thu, 07 Jun 2018   Prob (F-statistic):           2.73e-82
# Time:                        14:11:20   Log-Likelihood:                -4054.6
# No. Observations:                 606   AIC:                             8121.
# Df Residuals:                     600   BIC:                             8148.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.2568     17.424      0.244      0.807     -29.963      38.477
# x1            -1.1383      0.328     -3.471      0.001      -1.782      -0.494
# x2             1.0175      0.241      4.227      0.000       0.545       1.490
# x3             0.0006      0.000      2.908      0.004       0.000       0.001
# x4            -0.0008      0.000     -3.724      0.000      -0.001      -0.000
# x5             0.7045      1.315      0.536      0.592      -1.878       3.287
# ==============================================================================
# Omnibus:                     1166.293   Durbin-Watson:                   2.377
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1536701.157
# Skew:                          13.208   Prob(JB):                         0.00
# Kurtosis:                     248.279   Cond. No.                     8.87e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.87e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# nfl
# +++++++++++++++++++++++++++++++++
# Mean Absolute Error 241.70497816633994
# Mean Square Error 1333939.1431501934
# Root Mean-Square Error 1154.9628319345145
# +++++++++++++++++++++++++++++++++
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     8.846
# Date:                Thu, 07 Jun 2018   Prob (F-statistic):           3.26e-08
# Time:                        14:11:41   Log-Likelihood:                -7843.9
# No. Observations:                 926   AIC:                         1.570e+04
# Df Residuals:                     920   BIC:                         1.573e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         69.0908     60.044      1.151      0.250     -48.749     186.931
# x1            -0.3495      0.368     -0.951      0.342      -1.071       0.372
# x2             0.5991      0.178      3.365      0.001       0.250       0.948
# x3            -0.0001      5e-05     -2.264      0.024      -0.000   -1.51e-05
# x4             0.0002   6.47e-05      3.141      0.002    7.63e-05       0.000
# x5            12.1856      5.766      2.113      0.035       0.870      23.502
# ==============================================================================
# Omnibus:                     2331.687   Durbin-Watson:                   2.052
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         19992642.436
# Skew:                          25.388   Prob(JB):                         0.00
# Kurtosis:                     721.046   Cond. No.                     9.42e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.42e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# patriots
# +++++++++++++++++++++++++++++++++
# Mean Absolute Error 1199.4875197038841
# Mean Square Error 75667640.96406215
# Root Mean-Square Error 8698.714903022294
# +++++++++++++++++++++++++++++++++
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                     30.59
# Date:                Thu, 07 Jun 2018   Prob (F-statistic):           5.84e-29
# Time:                        14:12:17   Log-Likelihood:                -10280.
# No. Observations:                 980   AIC:                         2.057e+04
# Df Residuals:                     974   BIC:                         2.060e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        199.7508    515.097      0.388      0.698    -811.077    1210.578
# x1            -9.1381      0.904    -10.109      0.000     -10.912      -7.364
# x2            -0.0041      0.695     -0.006      0.995      -1.368       1.360
# x3             0.0038      0.000     10.146      0.000       0.003       0.005
# x4            -0.0059      0.001     -9.084      0.000      -0.007      -0.005
# x5            -7.3055     45.551     -0.160      0.873     -96.694      82.083
# ==============================================================================
# Omnibus:                     2462.153   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         23004808.305
# Skew:                          25.341   Prob(JB):                         0.00
# Kurtosis:                     751.875   Cond. No.                     4.26e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.26e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# sb49
# +++++++++++++++++++++++++++++++++
# Mean Absolute Error 2034.5423593344935
# Mean Square Error 283049322.7941336
# Root Mean-Square Error 16824.06974528261
# +++++++++++++++++++++++++++++++++
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     3.951
# Date:                Thu, 07 Jun 2018   Prob (F-statistic):            0.00157
# Time:                        14:13:16   Log-Likelihood:                -6489.0
# No. Observations:                 582   AIC:                         1.299e+04
# Df Residuals:                     576   BIC:                         1.302e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        651.7843   1453.592      0.448      0.654   -2203.203    3506.772
# x1            -0.5441      0.450     -1.209      0.227      -1.428       0.339
# x2             0.3334      0.440      0.758      0.449      -0.531       1.197
# x3         -1.354e-05   7.03e-05     -0.193      0.847      -0.000       0.000
# x4             0.0005      0.000      2.080      0.038    2.83e-05       0.001
# x5           -41.0986    110.013     -0.374      0.709    -257.174     174.976
# ==============================================================================
# Omnibus:                     1372.500   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          5025370.417
# Skew:                          20.606   Prob(JB):                         0.00
# Kurtosis:                     456.358   Cond. No.                     2.23e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.23e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# superbowl
# +++++++++++++++++++++++++++++++++
# Mean Absolute Error 4986.318947477098
# Mean Square Error 763795477.9265664
# Root Mean-Square Error 27636.85000007357
# +++++++++++++++++++++++++++++++++
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.215
# Model:                            OLS   Adj. R-squared:                  0.211
# Method:                 Least Squares   F-statistic:                     52.18
# Date:                Thu, 07 Jun 2018   Prob (F-statistic):           6.81e-48
# Time:                        14:14:53   Log-Likelihood:                -11145.
# No. Observations:                 957   AIC:                         2.230e+04
# Df Residuals:                     951   BIC:                         2.233e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1777.0210   1898.962      0.936      0.350   -1949.619    5503.662
# x1           -14.2914      2.439     -5.859      0.000     -19.078      -9.504
# x2            -0.4642      1.104     -0.421      0.674      -2.630       1.702
# x3             0.0019      0.000     14.596      0.000       0.002       0.002
# x4            -0.0042      0.001     -7.311      0.000      -0.005      -0.003
# x5           -57.7481    164.243     -0.352      0.725    -380.069     264.573
# ==============================================================================
# Omnibus:                     2215.831   Durbin-Watson:                   1.797
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         14129027.785
# Skew:                          20.708   Prob(JB):                         0.00
# Kurtosis:                     596.816   Cond. No.                     5.35e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.35e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import collections
Y = collections.deque(Y)
Y.rotate(-1)
Y = list(Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-24fc646de924> in <module>()
#       1 import collections
# ----> 2 Y = collections.deque(Y)
#       3 Y.rotate(-1)
#       4 Y = list(Y)
#
# NameError: name 'Y' is not defined
